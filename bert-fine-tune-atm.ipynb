# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %% [markdown]
# Run this once to download the transformers library.

# %%
# ! git clone https://github.com/huggingface/transformers

# %% [markdown]
# # Setup

# %%
# !pip install git+https://github.com/huggingface/transformers
# !pip list | grep -E 'transformers|tokenizers'

# %%
cd /content/gdrive/My Drive/transformers/examples/pytorch/language-modeling

# %%
# !pip install -r ./requirements.txt

# %% [markdown]
# # Run

# %%
input_file = "'content/gdrive/My Drive/transformers/examples/pytorch/language-modeling/wiki-simp.txt'"
output_model_dir = "'content/gdrive/My Drive/transformers/examples/pytorch/language-modeling/test-mlm'"

! python run_mlm.py --model_name_or_path bert-base-uncased \
                    --train_file $input_file \
                    --do_train \
                    --save_steps 1200 \
                    --output_dir $output_model_dir \
                    --per_device_train_batch_size 16 \
                    --gradient_accumulation_steps 4 \
                    --line_by_line

# %%
# out-of-the-box bert

# from transformers import AutoModelForMaskedLM, AutoTokenizer

# print('Loading Masked Language Model')
# mlm_tokenizer = AutoTokenizer.from_pretrained('bert-base-uncased')
# mlm_model = AutoModelForMaskedLM.from_pretrained('bert-base-uncased')

# mlm_tokenizer.save_pretrained('./no_test-mlm/')
# mlm_model.save_pretrained('./no_test-mlm/')
